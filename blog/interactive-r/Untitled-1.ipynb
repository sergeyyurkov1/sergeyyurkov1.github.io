# %% [raw]
# ---
# title: ""
# author: "Yurkov Sergey"
# date: "2024-01-01"
# categories: [python]
# format: html
# draft: true
# ---

# %%
library(plspm)

# %%
v.n = function(a,b)
{ # a - variable, b - a x number of times
    a = as.character(a)
    b = as.numeric(b)
    x = rep(a,b)
    y = 1:b
    z = paste0(x,y)
}

p = pspp_csv[,c(v.n("EU",3),v.n("SFO",4),v.n("IO",4),v.n("SO",4),v.n("SNF",6),v.n("DIS",4),v.n("DUI",4))] # table of data

head(p,n=5)

# %%
install.packages("languageserver")
# Out:
# also installing the dependencies 'remotes', 'R.methodsS3', 'R.oo', 'R.utils', 'cyclocomp', 'rex', 'brew', 'R.cache', 'collections', 'lintr', 'roxygen2', 'styler', 'xmlparsedata'
# package 'remotes' successfully unpacked and MD5 sums checked
# package 'R.methodsS3' successfully unpacked and MD5 sums checked
# package 'R.oo' successfully unpacked and MD5 sums checked
# package 'R.utils' successfully unpacked and MD5 sums checked
# package 'cyclocomp' successfully unpacked and MD5 sums checked
# package 'rex' successfully unpacked and MD5 sums checked
# package 'brew' successfully unpacked and MD5 sums checked
# package 'R.cache' successfully unpacked and MD5 sums checked
# package 'collections' successfully unpacked and MD5 sums checked
# package 'lintr' successfully unpacked and MD5 sums checked
# package 'roxygen2' successfully unpacked and MD5 sums checked
# package 'styler' successfully unpacked and MD5 sums checked
# ...

# %%
install.packages("seminr")
install.packages('readxl')
# Out:
# also installing the dependencies 'DiagrammeR', 'DiagrammeRsvg'
# package 'DiagrammeR' successfully unpacked and MD5 sums checked
# package 'DiagrammeRsvg' successfully unpacked and MD5 sums checked
# package 'seminr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\serge\AppData\Local\Temp\Rtmpc73djI\downloaded_packages
# package 'readxl' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\serge\AppData\Local\Temp\Rtmpc73djI\downloaded_packages

# %%
library(readxl)

# %%
data <- read_excel('36501977_按序号_微信疲劳调查[Updated]_208_206.xlsx')

# %%
data
# Out:
#     序号 提交答卷时间       所用时间 来源 来源详情 来自IP
# 1    2   2019/3/24 14:33:45 140秒    微信 N/A      49.94.156.33(江苏-南京)
# 2    3   2019/3/24 14:38:36 114秒    微信 N/A      223.104.35.186(安徽-合肥)
# 3    4   2019/3/24 14:40:55 103秒    微信 N/A      117.136.67.54(江苏-苏州)
# 4    5   2019/3/24 14:41:09 108秒    微信 N/A      117.136.103.248(安徽-合肥)
# 5    6   2019/3/24 14:50:30 125秒    微信 N/A      122.192.14.218(江苏-南京)
# 6    7   2019/3/24 14:50:48 128秒    微信 N/A      223.104.146.39(江苏-苏州)
# 7    8   2019/3/24 14:50:58 116秒    微信 N/A      223.104.4.250(江苏-苏州)
# 8    9   2019/3/24 14:51:16 155秒    微信 N/A      117.136.45.38(江苏-苏州)
# 9   10   2019/3/24 14:51:18 177秒    微信 N/A      117.136.67.90(江苏-苏州)
# 10  11   2019/3/24 14:51:52 201秒    微信 N/A      223.104.4.240(江苏-苏州)
# 11  12   2019/3/24 14:52:58 50秒     微信 N/A      117.136.68.44(江苏-苏州)
# 12  13   2019/3/24 14:53:03 208秒    微信 N/A      122.96.40.113(江苏-南京)
# 13  14   2019/3/24 14:54:11 113秒    微信 N/A      223.104.146.41(江苏-苏州)
# ...

# %%
colnames(data)
# Out:
#  [1] "序号"
#  [2] "提交答卷时间"
#  [3] "所用时间"
#  [4] "来源"
#  [5] "来源详情"
#  [6] "来自IP"
#  [7] "总分"
#  [8] "1、您使用微信吗？"
#  [9] "2、您是中国人吗？"
# [10] "3、您的年龄段："
# [11] "4、您的性别："
# [12] "5、请说明您目前的大学学位课程"
# [13] "6、请说明您在微信上的朋友数量"
# [14] "7、关于下列微信使用情况，请说明您的赞同或不赞同程度—我认为我使用微信的时间是过度的"
# [15] "7、我花费大量的时间在使用微信上"
# [16] "7、我比其他大多数人花更多时间使用微信"
# [17] "8、关于下列微信使用情况，请说明您的赞同或不赞同程度—微信上与我主要使用目的无关的功能常常让我感到心烦"
# [18] "8、我发现微信上好的功能不多,反而有很多不怎么样的功能"
# [19] "8、虽然微信努力通过增加新功能来帮助用户使用,但其实这些新功能效果并不好"
# [20] "8、微信提供的功能往往比我需要用这些功能完成的任务还复杂"
# [21] "9、关于下列微信使用情况，请说明您的赞同或不赞同程度—微信上过多的信息常常会让我感到心烦"
# [22] "9、每天微信上会有很多要处理的信息,我有一种被淹没在其中的感觉"
# [23] "9、微信上有很多关于朋友的信息,让我觉得处理这些信息是一种负担"
# [24] "9、我发现微信上只有很少一部分信息是我所需要的"
# [25] "10、关于下列微信使用情况，请说明您的赞同或不赞同程度—关心微信上朋友的状况耗费了我过多精力"
# [26] "10、处理微信上朋友的问题耗费了我过多精力"
# [27] "10、关照微信上的朋友耗费了我过多精力"
# [28] "10、浏览微信朋友发表的帖子耗费了我很多注意力"
# [29] "11、关于下列微信使用情况，请说明您的赞同或不赞同程度—有时使用微信会让我感到腻烦"
# [30] "11、有时使用微信会让我感到无趣"
# [31] "11、有时使用微信后会让我感到筋疲力尽"
# [32] "11、有时使用微信后会让我感到疲惫"
# [33] "11、我对微信上是否有新的事情发生并不是很感兴趣"
# ...
