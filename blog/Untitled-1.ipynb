# %% [raw]
# ---
# title: "Welcome To My Blog"
# author: "Yurkov Sergey"
# date: "2024-01-01"
# categories: [python]
# format: html
# ---

# %% [markdown]
# ![](thumbnail.jpg)

# %% [markdown]
# This is the second blog post. Welcome!

# %%
1 + 1
# Out:
# 2
